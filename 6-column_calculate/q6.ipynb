# %% [markdown]
# # Pregunta 6. Consulta que cree al menos una columna calculada.
#
# 1. Es decir, que la consulta cree un nuevo campo dependiendo de otro campo, o calculado a partir de otras columnas.
#
# 2. Ejemplo: a) campo Apto/NoApto dependiendo de las notas de alumnos b) cálculo imc a partir del peso y la altura.
#
# 3. Resultado final, Jupyter Notebook o proyecto Python con el código.

# %% [markdown]
# ### IMPORT
# ---

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Calculated column
# ---
#
# - La columna calculada es "no_hospitalization_required".
# - Calculo: el número de personas enfermas menos el número de personas hospitalisadas.
# Lo que quiere decir que esas personas enfermaron levemente y no necesitaron ser hospitalizadas.

# %%
data: pd.DataFrame = pd.read_csv("../data/cleaned_csv/3-question_results/cases.csv", index_col="case_id")
data["no_hospitalization_required"] = data['illnesses'] - data['hospitalizations']
data
# Out:
#          year     month       state                               location  \
# case_id
# 1        1998   January  California                             Restaurant
# 2        1998   January  California                                    NaN
# 3        1998   January  California                             Restaurant
# 4        1998   January  California                             Restaurant
# 5        1998   January  California                 Private Home/Residence
# ...       ...       ...         ...                                    ...
# 17391    2015  December   Wisconsin                             Restaurant
# 17392    2015  December   Wisconsin                 Private Home/Residence
# 17393    2015  December   Wisconsin  Nursing Home/Assisted Living Facility
# 17394    2015  December   Wisconsin                   Fast Food Restaurant
# 17395    2015  December     Wyoming                                    NaN
#
# ...
