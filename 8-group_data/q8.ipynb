# %% [markdown]
# # Pregunta 8. Consulta con datos agrupados por fecha.
#
# 1.  Es decir, que si los datos no estan agrupados, los tendrá que agrupar por fecha; ya sea por año, por mes o por día.
#
# 2. También debe mostrar un gráfico.
#
# 3. Resultado final, Jupyter Notebook o proyecto Python con el código y el gráfico.

# %% [markdown]
# ### IMPORT
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Datos agrupados
# ---

# %%
data: pd.DataFrame = pd.read_csv("../data/cleaned_csv/3-question_results/cases.csv", index_col="case_id")
group_by_year = data.groupby('month').agg(num_illnesses_year = ('illnesses', "sum"))
group_by_yers_XX = group_by_year.iloc[1:18,:]
group_by_yers_XX
# Out:
#            num_illnesses_year
# month
# August                  23303
# December                30335
# February                23794
# January                 26290
# July                    24340
# June                    29099
# March                   29227
# May                     31539
# November                27790
# October                 23399
# September               21117

# %% [markdown]
# ### Gráfico

# %%
group_by_yers_XX.plot(figsize=(20,5))
# Out:
# <AxesSubplot: xlabel='month'>
