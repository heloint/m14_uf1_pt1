# %%
import pandas as pd
import numpy as np

df_cases: pd.DataFrame = pd.read_csv('../data/cleaned_csv/cases.csv', sep=',')
df_food : pd.DataFrame = pd.read_csv('../data/cleaned_csv/food.csv', sep=',')

# %%
df_cases.replace('unknown', np.NaN)
# Out:
#        case_id  year     month       state  \
# 0            1  1998   January  California
# 1            2  1998   January  California
# 2            3  1998   January  California
# 3            4  1998   January  California
# 4            5  1998   January  California
# ...        ...   ...       ...         ...
# 18992    19115  2015  December   Wisconsin
# 18993    19116  2015  December   Wisconsin
# 18994    19117  2015  December   Wisconsin
# 18995    19118  2015  December   Wisconsin
# 18996    19119  2015  December     Wyoming
#
#                                     location                 species  \
# 0                                 Restaurant                     NaN
# 1                                        NaN                     NaN
# 2                                 Restaurant                     NaN
# 3                                 Restaurant         Scombroid toxin
# 4                     Private Home/Residence     Salmonella enterica
# ...                                      ...                     ...
# 18992                             Restaurant  Norovirus genogroup II
# 18993                 Private Home/Residence  Norovirus genogroup II
# 18994  Nursing Home/Assisted Living Facility  Norovirus genogroup II
# 18995                   Fast Food Restaurant  Norovirus genogroup II
# 18996                                    NaN                     NaN
#
#           status  illnesses  hospitalizations  fatalities
# 0            NaN         20               0.0         0.0
# 1            NaN        112               0.0         0.0
# 2            NaN         35               0.0         0.0
# 3      Confirmed          4               0.0         0.0
# 4      Confirmed         26               3.0         0.0
# ...          ...        ...               ...         ...
# 18992  Confirmed          4               0.0         0.0
# 18993  Confirmed         16               0.0         0.0
# 18994  Confirmed         43               3.0         0.0
# 18995  Confirmed          5               0.0         0.0
# 18996        NaN          3               0.0         0.0
#
# [18997 rows x 10 columns]

# %%
df_food.replace('unknown', np.NaN)
# Out:
#        case_id     food
# 0            1      NaN
# 1            2  custard
# 2            3      NaN
# 3            4     fish
# 4            4      ahi
# ...        ...      ...
# 29630    19115      NaN
# 29631    19116    salsa
# 29632    19117      NaN
# 29633    19118      NaN
# 29634    19119      NaN
#
# [29635 rows x 2 columns]

# %%
df_cases['status'].replace(np.NaN, 'unknown')
# Out:
# 0          unknown
# 1          unknown
# 2          unknown
# 3        Confirmed
# 4        Confirmed
#            ...
# 18992    Confirmed
# 18993    Confirmed
# 18994    Confirmed
# 18995    Confirmed
# 18996      unknown
# Name: status, Length: 18997, dtype: object
